# %% [markdown]
# # Projet 5 - requêtes SQL

# %%
# chargement formateur de cellules notebook
# %load_ext lab_black

# %% [markdown]
# ## Connexion à la base de donnée

# %%
# chargement extension SQL ipython

# %load_ext sql
# %sql sqlite:///olist.db

# %% [markdown]
# ## Nom des tables

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///olist.db
# Done.
# [('customers',),
#  ('geoloc',),
#  ('order_items',),
#  ('order_pymts',),
#  ('order_reviews',),
#  ('orders',),
#  ('products',),
#  ('sellers',),
#  ('translation',)]

# %% [markdown]
# ## Examen de la structure des tables
#
#  - noms de colonnes
#  - types de données

# %% [markdown]
# ### customers

# %%
# %%sql
# PRAGMA table_info(customers);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'customer_id', 'TEXT', 0, None, 0),
#  (2, 'customer_unique_id', 'TEXT', 0, None, 0),
#  (3, 'customer_zip_code_prefix', 'BIGINT', 0, None, 0),
#  (4, 'customer_city', 'TEXT', 0, None, 0),
#  (5, 'customer_state', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### geoloc

# %%
# %%sql
# PRAGMA table_info(geoloc);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'geolocation_zip_code_prefix', 'BIGINT', 0, None, 0),
#  (2, 'geolocation_lat', 'FLOAT', 0, None, 0),
#  (3, 'geolocation_lng', 'FLOAT', 0, None, 0),
#  (4, 'geolocation_city', 'TEXT', 0, None, 0),
#  (5, 'geolocation_state', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### order_items

# %%
# %%sql
# PRAGMA table_info(order_items);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'order_id', 'TEXT', 0, None, 0),
#  (2, 'order_item_id', 'BIGINT', 0, None, 0),
#  (3, 'product_id', 'TEXT', 0, None, 0),
#  (4, 'seller_id', 'TEXT', 0, None, 0),
#  (5, 'shipping_limit_date', 'TEXT', 0, None, 0),
#  (6, 'price', 'FLOAT', 0, None, 0),
#  (7, 'freight_value', 'FLOAT', 0, None, 0)]

# %% [markdown]
# ### order_pymts

# %%
# %%sql
# PRAGMA table_info(order_pymts);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'order_id', 'TEXT', 0, None, 0),
#  (2, 'payment_sequential', 'BIGINT', 0, None, 0),
#  (3, 'payment_type', 'TEXT', 0, None, 0),
#  (4, 'payment_installments', 'BIGINT', 0, None, 0),
#  (5, 'payment_value', 'FLOAT', 0, None, 0)]

# %% [markdown]
# ### order_reviews

# %%
# %%sql
# PRAGMA table_info(order_reviews);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'review_id', 'TEXT', 0, None, 0),
#  (2, 'order_id', 'TEXT', 0, None, 0),
#  (3, 'review_score', 'BIGINT', 0, None, 0),
#  (4, 'review_comment_title', 'TEXT', 0, None, 0),
#  (5, 'review_comment_message', 'TEXT', 0, None, 0),
#  (6, 'review_creation_date', 'TEXT', 0, None, 0),
#  (7, 'review_answer_timestamp', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### orders

# %%
# %%sql
# PRAGMA table_info(orders);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'order_id', 'TEXT', 0, None, 0),
#  (2, 'customer_id', 'TEXT', 0, None, 0),
#  (3, 'order_status', 'TEXT', 0, None, 0),
#  (4, 'order_purchase_timestamp', 'TEXT', 0, None, 0),
#  (5, 'order_approved_at', 'TEXT', 0, None, 0),
#  (6, 'order_delivered_carrier_date', 'TEXT', 0, None, 0),
#  (7, 'order_delivered_customer_date', 'TEXT', 0, None, 0),
#  (8, 'order_estimated_delivery_date', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### products

# %%
# %%sql
# PRAGMA table_info(products);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'product_id', 'TEXT', 0, None, 0),
#  (2, 'product_category_name', 'TEXT', 0, None, 0),
#  (3, 'product_name_lenght', 'FLOAT', 0, None, 0),
#  (4, 'product_description_lenght', 'FLOAT', 0, None, 0),
#  (5, 'product_photos_qty', 'FLOAT', 0, None, 0),
#  (6, 'product_weight_g', 'FLOAT', 0, None, 0),
#  (7, 'product_length_cm', 'FLOAT', 0, None, 0),
#  (8, 'product_height_cm', 'FLOAT', 0, None, 0),
#  (9, 'product_width_cm', 'FLOAT', 0, None, 0)]

# %% [markdown]
# ### sellers

# %%
# %%sql
# PRAGMA table_info(sellers);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'seller_id', 'TEXT', 0, None, 0),
#  (2, 'seller_zip_code_prefix', 'BIGINT', 0, None, 0),
#  (3, 'seller_city', 'TEXT', 0, None, 0),
#  (4, 'seller_state', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### translation

# %%
# %%sql
# PRAGMA table_info(translation);
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'index', 'BIGINT', 0, None, 0),
#  (1, 'product_category_name', 'TEXT', 0, None, 0),
#  (2, 'product_category_name_english', 'TEXT', 0, None, 0)]

# %% [markdown]
# ## Requêtes SQL simples

# %% [markdown]
# ### Selection de toutes les données d'une table

# %%
# %%sql
# SELECT * FROM customers LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, '06b8999e2fba1a1fbc88172c00ba8bc7', '861eff4711a542e4b93843c6dd7febb0', 14409, 'franca', 'SP'),
#  (1, '18955e83d337fd6b2def6b18a428ac77', '290c77bc529b7ac935b93aa66c333dc3', 9790, 'sao bernardo do campo', 'SP'),
#  (2, '4e7b3e00288586ebd08712fdd0374a03', '060e732b5b29e8181a18229c7b0b2b5e', 1151, 'sao paulo', 'SP'),
#  (3, 'b2b6027bc5c5109e529d4dc6358b12c3', '259dac757896d24d7702b9acbbff3f3c', 8775, 'mogi das cruzes', 'SP'),
#  (4, '4f2d8ab171c80ec8364f7c12e35b23ad', '345ecd01c38d18a9036ed96c73b8d066', 13056, 'campinas', 'SP')]

# %% [markdown]
# ### Selection de colonnes spécifiques

# %%
# %%sql
# SELECT customer_city FROM customers LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [('franca',),
#  ('sao bernardo do campo',),
#  ('sao paulo',),
#  ('mogi das cruzes',),
#  ('campinas',)]

# %% [markdown]
# ### Filtrage des résultats avec une condition

# %%
# %%sql
# SELECT * FROM customers WHERE customer_city ='franca' LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, '06b8999e2fba1a1fbc88172c00ba8bc7', '861eff4711a542e4b93843c6dd7febb0', 14409, 'franca', 'SP'),
#  (241, 'b9885472fa562ddc1cb5333a42b654fc', '2767ebe1fedf70562aa588a37a23080a', 14401, 'franca', 'SP'),
#  (650, '5dca924cc99eea2dc5ba40d11ec5dd0f', '2761fee7f378f0a8d7682d8a3fa07ab1', 14409, 'franca', 'SP'),
#  (700, 'de3fa59dd658cd8b47a1634125047c01', 'fa87e5558d2010f19641ca49363d5a1a', 14405, 'franca', 'SP'),
#  (1894, '0489975a325480c9e385e9f135bb13c3', 'b577af9a54b023b4bcc51f69bb937f1c', 14406, 'franca', 'SP')]

# %% [markdown]
# ### Tri et Agrégation

# %% [markdown]
# #### Tri des données

# %%
# %%sql
# SELECT * FROM customers ORDER BY customer_city ASC LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(19445, 'f11eb8f0b8b87510a93e3e1aa10b0ade', '64ee476500a01beb94df40f97a108c50', 38540, 'abadia dos dourados', 'MG'),
#  (44027, 'a23e3f9a2b656b23b7e52075964b42cd', 'afddf43a03a9941624ed42c0b2c17280', 38540, 'abadia dos dourados', 'MG'),
#  (74529, '9e01f714a2b3b8962c222cf2b74c20dc', 'e1feae9083c4c2895ddf6dc80526a85d', 38540, 'abadia dos dourados', 'MG'),
#  (42307, '576d71ddb21b21763cfedce73b902180', '8d76b559181609308fcae630ea64cd61', 72940, 'abadiania', 'GO'),
#  (5205, '5e9e1ae42e02df93e9a591e86fd531a3', '28af9604f7830ef6d1230fb575c39eb1', 35620, 'abaete', 'MG')]

# %% [markdown]
# #### Agregation

# %%
# %%sql
# SELECT * FROM order_pymts LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(0, 'b81ef226f3fe1789b1e8b2acac839d17', 1, 'credit_card', 8, 99.33),
#  (1, 'a9810da82917af2d9aefd1278f1dcfa0', 1, 'credit_card', 1, 24.39),
#  (2, '25e8ea4e93396b6fa0d3dd708e76c1bd', 1, 'credit_card', 1, 65.71),
#  (3, 'ba78997921bbcdc1373bb41e913ab953', 1, 'credit_card', 8, 107.78),
#  (4, '42fdf880ba16b47b59251dd489d4441a', 1, 'credit_card', 2, 128.45)]

# %%
# %%sql
# SELECT COUNT(*), AVG(payment_value) FROM order_pymts
# Out:
#  * sqlite:///olist.db
# Done.
# [(103886, 154.10038041698365)]

# %% [markdown]
# ### Jointure
#
# ex: joindre la table orders et customers pour obtenir une liste des commandes avec les codes postaux des clients

# %%
# %%sql
# SELECT o.order_id, c.customer_zip_code_prefix
# FROM orders o
# JOIN customers c ON o.customer_id = c.customer_id
# LIMIT 10;
# Out:
#  * sqlite:///olist.db
# Done.
# [('e481f51cbdc54678b7cc49136f2d6af7', 3149),
#  ('53cdb2fc8bc7dce0b6741e2150273451', 47813),
#  ('47770eb9100c2d0c44946d9cf07ec65d', 75265),
#  ('949d5b44dbf5de918fe9c16f97b45f8a', 59296),
#  ('ad21c59c0840e6cb83a9ceb5573f8159', 9195),
#  ('a4591c265e18cb1dcee52889e2d8acc3', 86320),
#  ('136cce7faa42fdb2cefd53fdc79a6098', 98900),
#  ('6514b8ad8028c9f2cc2374ded245783f', 26525),
#  ('76c6e866289321a7c93b82b54852dc33', 99655),
#  ('e69bfb5eb88e0ed6a785585b27e16dbf', 18075)]

# %% [markdown]
# ### Autres

# %%
# Récupérer les noms des tables
tables = %sql SELECT name FROM sqlite_master WHERE type='table';

# Afficher les informations de chaque table
for table in tables:
    print(f"--- Informations de la table {table[0]} ---")
    info = %sql PRAGMA table_info({table[0]});
    for column in info:
        print(column)
    print("\n")
# Out:
#  * sqlite:///olist.db
# Done.
# --- Informations de la table customers ---
#  * sqlite:///olist.db
# Done.
# (0, 'index', 'BIGINT', 0, None, 0)
# (1, 'customer_id', 'TEXT', 0, None, 0)
# (2, 'customer_unique_id', 'TEXT', 0, None, 0)
# (3, 'customer_zip_code_prefix', 'BIGINT', 0, None, 0)
# (4, 'customer_city', 'TEXT', 0, None, 0)
# (5, 'customer_state', 'TEXT', 0, None, 0)
#
#
# --- Informations de la table geoloc ---
#  * sqlite:///olist.db
# Done.
# (0, 'index', 'BIGINT', 0, None, 0)
# (1, 'geolocation_zip_code_prefix', 'BIGINT', 0, None, 0)
# (2, 'geolocation_lat', 'FLOAT', 0, None, 0)
# (3, 'geolocation_lng', 'FLOAT', 0, None, 0)
# (4, 'geolocation_city', 'TEXT', 0, None, 0)
# (5, 'geolocation_state', 'TEXT', 0, None, 0)
#
#
# --- Informations de la table order_items ---
#  * sqlite:///olist.db
# Done.
# (0, 'index', 'BIGINT', 0, None, 0)
# (1, 'order_id', 'TEXT', 0, None, 0)
# (2, 'order_item_id', 'BIGINT', 0, None, 0)
# (3, 'product_id', 'TEXT', 0, None, 0)
# ...

# %%
# %%sql
# -- requête des status possibles d une commande
# SELECT DISTINCT order_status FROM orders;
# Out:
#  * sqlite:///olist.db
# Done.
# [('delivered',),
#  ('invoiced',),
#  ('shipped',),
#  ('processing',),
#  ('unavailable',),
#  ('canceled',),
#  ('created',),
#  ('approved',)]

# %%
# %%sql
# -- requête test
# SELECT DISTINCT order_purchase_timestamp FROM orders LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [('2017-10-02 10:56:33',),
#  ('2018-07-24 20:41:37',),
#  ('2018-08-08 08:38:49',),
#  ('2017-11-18 19:28:06',),
#  ('2018-02-13 21:18:39',)]

# %% [markdown]
# ## REQUETE #1

# %%
# %%sql
# SELECT order_id, customer_id, order_purchase_timestamp, order_estimated_delivery_date, order_delivered_customer_date
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
#   AND DATE(order_delivered_customer_date) >= DATE('now', '-3 months')
# ORDER BY order_delivered_customer_date DESC;
# Out:
#  * sqlite:///olist.db
# Done.
# []

# %%
# %%sql
# SELECT order_id, customer_id, order_purchase_timestamp, order_estimated_delivery_date, order_delivered_customer_date
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
# --AND DATE(order_delivered_customer_date) >= DATE('now', '-3 months')
# ORDER BY order_delivered_customer_date DESC;
# Out:
#  * sqlite:///olist.db
# Done.
# [('7e708aed151d6a8601ce8f2eaa712bf4', '033fab69968b0d69099d64423831a236', '2018-06-02 18:37:14', '2018-07-13 00:00:00', '2018-10-17 13:22:46'),
#  ('450cb96c63e1e5b49d34f223f67976d2', '27ae7c8a8fc20ce80d96f01b6f19961b', '2018-05-21 06:48:46', '2018-06-27 00:00:00', '2018-10-11 16:41:14'),
#  ('b2997e1d7061605e9285496c581d1fbd', '9e83d47684eb1a58b1c31830f5de10ac', '2018-07-30 09:08:06', '2018-08-14 00:00:00', '2018-10-02 00:18:50'),
#  ('a2b4be96b53022618030c17ed437604d', 'ffa87b4246c4848711afb512bd51f161', '2018-07-22 09:54:03', '2018-08-17 00:00:00', '2018-09-27 02:24:33'),
#  ('7d09831e67caa193da82cfea3bee7aa5', '1409b2945191b7aff1975ba2ce9918c5', '2018-08-05 17:11:44', '2018-08-20 00:00:00', '2018-09-25 00:47:25'),
#  ('f23681a0fffdb8051c674707c7e912ef', '7930549f156eea2b01b0fc2fdd323063', '2018-07-15 02:11:15', '2018-08-06 00:00:00', '2018-09-21 23:46:29'),
# ...

# %%
# %%sql
# SELECT *
# FROM orders
# ORDER BY order_purchase_timestamp DESC
# LIMIT 1;
# Out:
#  * sqlite:///olist.db
# Done.
# [(60938, '10a045cdf6a5650c21e9cfeb60384c16', 'a4b417188addbc05b26b72d5e44837a1', 'canceled', '2018-10-17 17:30:18', None, None, None, '2018-10-30 00:00:00')]

# %%
## la date de la dernière commande de la base de donnée semble être le 17 octobre 2018
## on va modifier le script pour que la date du jour soit celle ci

# %%
# %%sql
# SELECT order_id, customer_id, order_purchase_timestamp, order_estimated_delivery_date, order_delivered_customer_date
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
#   AND DATE(order_delivered_customer_date) >= DATE('2018-10-17', '-3 months')
# ORDER BY order_delivered_customer_date DESC;
# Out:
#  * sqlite:///olist.db
# Done.
# [('7e708aed151d6a8601ce8f2eaa712bf4', '033fab69968b0d69099d64423831a236', '2018-06-02 18:37:14', '2018-07-13 00:00:00', '2018-10-17 13:22:46'),
#  ('450cb96c63e1e5b49d34f223f67976d2', '27ae7c8a8fc20ce80d96f01b6f19961b', '2018-05-21 06:48:46', '2018-06-27 00:00:00', '2018-10-11 16:41:14'),
#  ('b2997e1d7061605e9285496c581d1fbd', '9e83d47684eb1a58b1c31830f5de10ac', '2018-07-30 09:08:06', '2018-08-14 00:00:00', '2018-10-02 00:18:50'),
#  ('a2b4be96b53022618030c17ed437604d', 'ffa87b4246c4848711afb512bd51f161', '2018-07-22 09:54:03', '2018-08-17 00:00:00', '2018-09-27 02:24:33'),
#  ('7d09831e67caa193da82cfea3bee7aa5', '1409b2945191b7aff1975ba2ce9918c5', '2018-08-05 17:11:44', '2018-08-20 00:00:00', '2018-09-25 00:47:25'),
#  ('f23681a0fffdb8051c674707c7e912ef', '7930549f156eea2b01b0fc2fdd323063', '2018-07-15 02:11:15', '2018-08-06 00:00:00', '2018-09-21 23:46:29'),
# ...

# %% [markdown]
# Requête #1 sans hardcode de la date la plus récente

# %%
# %%sql
# SELECT order_id, customer_id, order_purchase_timestamp, order_estimated_delivery_date, order_delivered_customer_date
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
#   AND DATE(order_delivered_customer_date) >= DATE((SELECT MAX(order_purchase_timestamp) FROM orders), '-3 months')
# ORDER BY order_delivered_customer_date DESC;
# Out:
#  * sqlite:///olist.db
# Done.
# [('7e708aed151d6a8601ce8f2eaa712bf4', '033fab69968b0d69099d64423831a236', '2018-06-02 18:37:14', '2018-07-13 00:00:00', '2018-10-17 13:22:46'),
#  ('450cb96c63e1e5b49d34f223f67976d2', '27ae7c8a8fc20ce80d96f01b6f19961b', '2018-05-21 06:48:46', '2018-06-27 00:00:00', '2018-10-11 16:41:14'),
#  ('b2997e1d7061605e9285496c581d1fbd', '9e83d47684eb1a58b1c31830f5de10ac', '2018-07-30 09:08:06', '2018-08-14 00:00:00', '2018-10-02 00:18:50'),
#  ('a2b4be96b53022618030c17ed437604d', 'ffa87b4246c4848711afb512bd51f161', '2018-07-22 09:54:03', '2018-08-17 00:00:00', '2018-09-27 02:24:33'),
#  ('7d09831e67caa193da82cfea3bee7aa5', '1409b2945191b7aff1975ba2ce9918c5', '2018-08-05 17:11:44', '2018-08-20 00:00:00', '2018-09-25 00:47:25'),
#  ('f23681a0fffdb8051c674707c7e912ef', '7930549f156eea2b01b0fc2fdd323063', '2018-07-15 02:11:15', '2018-08-06 00:00:00', '2018-09-21 23:46:29'),
# ...

# %% [markdown]
# Compte du nombre d'enregistrements résultants de la requête #2

# %%
# %%sql
# SELECT COUNT(*) AS total_deliveries
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
#   AND DATE(order_delivered_customer_date) >= DATE('2018-10-17', '-3 months');
# Out:
#  * sqlite:///olist.db
# Done.
# [(367,)]

# %%
# %%sql
# SELECT COUNT(*) AS total_deliveries
# FROM orders
# WHERE order_status <> 'canceled'
#   AND order_delivered_customer_date IS NOT NULL
#   AND DATE(order_delivered_customer_date) > DATE(order_estimated_delivery_date, '+3 days')
#   AND DATE(order_delivered_customer_date) >= DATE((SELECT MAX(order_purchase_timestamp) FROM orders), '-3 months');
# Out:
#  * sqlite:///olist.db
# Done.
# [(367,)]

# %% [markdown]
# ## REQUETE #2

# %%
# %%sql
# SELECT s.seller_id, s.seller_city, s.seller_state, SUM(oi.price + oi.freight_value) AS total_revenue
# FROM sellers AS s
# JOIN order_items AS oi ON s.seller_id = oi.seller_id
# JOIN orders AS o ON oi.order_id = o.order_id
# WHERE o.order_status = 'delivered'
# GROUP BY s.seller_id, s.seller_city, s.seller_state
# HAVING total_revenue > 100000
# ORDER BY total_revenue DESC;
# Out:
#  * sqlite:///olist.db
# Done.
# [('4869f7a5dfa277a7dca6462dcf3b52b2', 'guariba', 'SP', 247007.06000000023),
#  ('7c67e1448b00f6e969d365cea6b010ab', 'itaquaquecetuba', 'SP', 237806.68999999983),
#  ('4a3ca9315b744ce9f8e9374361493884', 'ibitinga', 'SP', 231220.4300000005),
#  ('53243585a1d6dc2643021fd1853d8905', 'lauro de freitas', 'BA', 230797.02000000037),
#  ('fa1c13f2614d7b5c4749cbc52fecda94', 'sumare', 'SP', 200833.49999999985),
#  ('da8622b14eb17ae2831f4ac5b9dab84a', 'piracicaba', 'SP', 184706.7799999995),
#  ('7e93a43ef30c4f03f38b393420bc753a', 'barueri', 'SP', 171973.55000000013),
#  ('1025f0e2d44d7041d6cf58b6550e0bfa', 'sao paulo', 'SP', 171924.96000000002),
#  ('7a67c85e85bb2ce8582c35f2203ad736', 'sao paulo', 'SP', 160278.52000000016),
#  ('955fee9216a65b617aa5c0531780ce60', 'sao paulo', 'SP', 156606.47999999937),
#  ('6560211a19b47992c3666cc44a7e94c0', 'sao paulo', 'SP', 148050.94000000067),
# ...

# %% [markdown]
# ## REQUETE #3

# %%
# %%sql
# SELECT s.seller_id, MIN(o.order_purchase_timestamp) AS first_sale_date, COUNT(oi.product_id) AS total_products_sold
# FROM sellers s
# JOIN order_items oi ON s.seller_id = oi.seller_id
# JOIN orders o ON oi.order_id = o.order_id
# GROUP BY s.seller_id
# HAVING first_sale_date >= DATE('2018-10-17', '-3 months')
# AND total_products_sold > 30;
# Out:
#  * sqlite:///olist.db
# Done.
# [('240b9776d844d37535668549a396af32', '2018-07-17 13:48:59', 36),
#  ('81f89e42267213cb94da7ddc301651da', '2018-08-08 12:45:12', 52),
#  ('d13e50eaa47b4cbe9eb81465865d8cfc', '2018-08-04 09:09:37', 69)]

# %% [markdown]
# Requête #3 sans hardcode de la date la plus récente

# %%
# %%sql
# SELECT s.seller_id, MIN(o.order_purchase_timestamp) AS first_sale_date, COUNT(oi.product_id) AS total_products_sold
# FROM sellers s
# JOIN order_items oi ON s.seller_id = oi.seller_id
# JOIN orders o ON oi.order_id = o.order_id
# GROUP BY s.seller_id
# HAVING first_sale_date >= DATE((SELECT MAX(order_purchase_timestamp) FROM orders), '-3 months')
# AND total_products_sold > 30;
# Out:
#  * sqlite:///olist.db
# Done.
# [('240b9776d844d37535668549a396af32', '2018-07-17 13:48:59', 36),
#  ('81f89e42267213cb94da7ddc301651da', '2018-08-08 12:45:12', 52),
#  ('d13e50eaa47b4cbe9eb81465865d8cfc', '2018-08-04 09:09:37', 69)]

# %% [markdown]
# ## REQUETE #4

# %%
# %%sql
# SELECT c.customer_zip_code_prefix AS postal_code, AVG(r.review_score) AS average_review_score, COUNT(o.order_id) AS total_orders
# FROM customers c
# JOIN orders o ON c.customer_id = o.customer_id
# JOIN order_reviews r ON o.order_id = r.order_id
# WHERE o.order_purchase_timestamp >= DATE('2018-10-17', '-12 months')
# GROUP BY c.customer_zip_code_prefix
# HAVING COUNT(o.order_id) > 30
# ORDER BY AVG(r.review_score) ASC
# LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(22753, 2.8085106382978724, 47),
#  (22770, 3.135135135135135, 37),
#  (22793, 3.2333333333333334, 90),
#  (21321, 3.2777777777777777, 36),
#  (22780, 3.3513513513513513, 37)]

# %% [markdown]
# Requête #4 sans hardcode de la date la plus récente

# %%
# %%sql
# SELECT c.customer_zip_code_prefix AS postal_code, AVG(r.review_score) AS average_review_score, COUNT(o.order_id) AS total_orders
# FROM customers c
# JOIN orders o ON c.customer_id = o.customer_id
# JOIN order_reviews r ON o.order_id = r.order_id
# WHERE o.order_purchase_timestamp >= DATE((SELECT MAX(order_purchase_timestamp) FROM orders), '-12 months')
# GROUP BY c.customer_zip_code_prefix
# HAVING COUNT(o.order_id) > 30
# ORDER BY AVG(r.review_score) ASC
# LIMIT 5;
# Out:
#  * sqlite:///olist.db
# Done.
# [(22753, 2.8085106382978724, 47),
#  (22770, 3.135135135135135, 37),
#  (22793, 3.2333333333333334, 90),
#  (21321, 3.2777777777777777, 36),
#  (22780, 3.3513513513513513, 37)]
